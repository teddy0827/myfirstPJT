# %%
import pandas as pd
import numpy as np

# 엑셀 파일에서 데이터 불러오기
df = pd.read_csv("c:/py_data/PDS211.1_WF075040_WF075030_20240716235504_11_csv.csv")



# die x, die y, step pitch x, step pitch y 값 추출
die_x = df['DieX']
die_y = df['DieY']
step_pitch_x = df['STEP_PITCH_X']
step_pitch_y = df['STEP_PITCH_Y']
inshot_x = df['coordinate_X']
inshot_y = df['coordinate_Y']
map_shift_x = df['MAP_SHIFT_X']
map_shift_y = df['MAP_SHIFT_Y']



# x, y 좌표 계산
x = die_x * step_pitch_x + map_shift_x + inshot_x
y = die_y * step_pitch_y + map_shift_y + inshot_y
rx = inshot_x
ry = inshot_y


# X_dx 데이터 구성 (k5 계산 시만 -y 사용, 3차항 포함)
X_dx = np.vstack([
    np.ones(len(x)), (x)/10**6, (-y)/10**6, (x**2)/10**12, (x*y)/10**12, (y**2)/10**12, (x**3)/10**15, (x**2*y)/10**15, (x*y**2)/10**15, (y**3)/10**15,
                     (rx)/10**6, (-ry)/10**6, (rx**2)/10**9, (rx*ry)/10**9, (ry**2)/10**9, (rx**3)/10**12, (rx**2*ry)/10**12, (rx*ry**2)/10**12, (ry**3)/10**12
]).T

# X_dy 데이터 구성 (3차항 포함, y를 그대로 사용)
X_dy = np.vstack([
    np.ones(len(y)), (y)/10**6, (x)/10**6, (y**2)/10**12, (y*x)/10**12, (x**2)/10**12, (y**3)/10**15, (y**2*x)/10**15, (y*x**2)/10**15, (x**3)/10**15,
                     (ry)/10**6, (rx)/10**6, (ry**2)/10**9, (ry*rx)/10**9, (rx**2)/10**9, (ry**3)/10**12, (ry**2*rx)/10**12, (ry*rx**2)/10**12, (rx**3)/10**12
]).T



# Y_dx, Y_dy 데이터
Y_dx = df['X_reg']
Y_dy = df['Y_reg']



# 최소자승법으로 dx의 계수 구하기 (X_dx 사용)
coeff_dx = np.linalg.lstsq(X_dx, Y_dx, rcond=None)[0]

# 최소자승법으로 dy의 계수 구하기 (X_dy 사용)
coeff_dy = np.linalg.lstsq(X_dy, Y_dy, rcond=None)[0]



# dx의 결과 출력 (3차항 포함 계수명 추가)
print("Coefficients for misalign x(um):")
print(f"WK1 (Offset x): {coeff_dx[0]}")
print(f"WK3 (Scale x): {coeff_dx[1]}")
print(f"WK5 (Rotation x, with -y): {coeff_dx[2]}")  # 여기서 -y 반영됨
print(f"WK7 (x^2): {coeff_dx[3]}")
print(f"WK9 (xy): {coeff_dx[4]}")
print(f"WK11 (y^2): {coeff_dx[5]}")
print(f"WK13 (x^3): {coeff_dx[6]}")
print(f"WK15 (x^2*y): {coeff_dx[7]}")
print(f"WK17 (x*y^2): {coeff_dx[8]}")
print(f"WK19 (y^3): {coeff_dx[9]}")

print(f"RK3 (Scale x): {coeff_dx[10]}")
print(f"RK5 (Rotation x, with -y): {coeff_dx[11]}")  # 여기서 -y 반영됨
print(f"RK7 (x^2): {coeff_dx[12]}")
print(f"RK9 (xy): {coeff_dx[13]}")
print(f"RK11 (y^2): {coeff_dx[14]}")
print(f"RK13 (x^3): {coeff_dx[15]}")
print(f"RK15 (x^2*y): {coeff_dx[16]}")
print(f"RK17 (x*y^2): {coeff_dx[17]}")
print(f"RK19 (y^3): {coeff_dx[18]}")


# dy의 결과 출력 (3차항 포함 계수명 추가)
print("\nCoefficients for misalign y(um):")
print(f"WK2 (Offset y): {coeff_dy[0]}")
print(f"WK4 (Scale y): {coeff_dy[1]}")
print(f"WK6 (Rotation y): {coeff_dy[2]}")
print(f"WK8 (x^2): {coeff_dy[3]}")
print(f"WK10 (xy): {coeff_dy[4]}")
print(f"WK12 (y^2): {coeff_dy[5]}")
print(f"WK14 (x^3): {coeff_dy[6]}")
print(f"WK16 (x^2*y): {coeff_dy[7]}")
print(f"WK18 (x*y^2): {coeff_dy[8]}")
print(f"WK20 (y^3): {coeff_dy[9]}")

print(f"RK4 (Scale y): {coeff_dy[10]}")
print(f"RK6 (Rotation y): {coeff_dy[11]}")
print(f"RK8 (x^2): {coeff_dy[12]}")
print(f"RK10 (xy): {coeff_dy[13]}")
print(f"RK12 (y^2): {coeff_dy[14]}")
print(f"RK14 (x^3): {coeff_dy[15]}")
print(f"RK16 (x^2*y): {coeff_dy[16]}")
print(f"RK18 (x*y^2): {coeff_dy[17]}")
print(f"RK20 (y^3): {coeff_dy[18]}")
# Out:
# Coefficients for misalign x(um):
# WK1 (Offset x): 0.00047665410580924116
# WK3 (Scale x): -0.009719673617917916
# WK5 (Rotation x, with -y): -0.0008331704898858455
# WK7 (x^2): -0.005658286609556847
# WK9 (xy): 0.023013160654036365
# WK11 (y^2): -0.001367725117804953
# WK13 (x^3): -0.0005326135406948457
# WK15 (x^2*y): 0.00019892527471932945
# WK17 (x*y^2): -0.0006520022982278321
# WK19 (y^3): 8.264304297955067e-05
# RK3 (Scale x): 0.14105370647503196
# RK5 (Rotation x, with -y): 0.0015503259763927674
# RK7 (x^2): -0.002039878026246425
# RK9 (xy): -0.0007219954169213744
# RK11 (y^2): 0.00014002783751255462
# RK13 (x^3): -0.0009314668102600254
# RK15 (x^2*y): 3.262115024611042e-05
# RK17 (x*y^2): -0.00029222620012317517
# RK19 (y^3): 4.935315855063385e-05
#
# Coefficients for misalign y(um):
# WK2 (Offset y): -0.0003262137663304887
# WK4 (Scale y): -0.015590774673435509
# WK6 (Rotation y): 0.001171734667610919
# WK8 (x^2): 0.011146075580381425
# WK10 (xy): 0.0008202349429851517
# WK12 (y^2): -0.011294477157863638
# WK14 (x^3): -0.0001621756196596526
# WK16 (x^2*y): -0.0001829870452619172
# WK18 (x*y^2): 0.00013196563410516288
# WK20 (y^3): -9.49099757877165e-05
# RK4 (Scale y): 0.039541962444764316
# RK6 (Rotation y): 0.06542096923354458
# RK8 (x^2): -0.00012355878619401097
# RK10 (xy): 0.00054329540219192
# RK12 (y^2): 0.0008018464164773163
# RK14 (x^3): -1.0276878505499857e-05
# RK16 (x^2*y): 8.057633975269962e-06
# RK18 (x*y^2): -0.00017271217627639707
# RK20 (y^3): -0.0005109270461176257

# %% [markdown]
# ### RK20 제거

# %%
import pandas as pd
import numpy as np

# 엑셀 파일에서 데이터 불러오기
df = pd.read_csv("c:/py_data/PDS211.1_WF075040_WF075030_20240716235504_11_csv.csv")



# die x, die y, step pitch x, step pitch y 값 추출
die_x = df['DieX']
die_y = df['DieY']
step_pitch_x = df['STEP_PITCH_X']
step_pitch_y = df['STEP_PITCH_Y']
inshot_x = df['coordinate_X']
inshot_y = df['coordinate_Y']
map_shift_x = df['MAP_SHIFT_X']
map_shift_y = df['MAP_SHIFT_Y']



# x, y 좌표 계산
x = die_x * step_pitch_x + map_shift_x + inshot_x
y = die_y * step_pitch_y + map_shift_y + inshot_y
rx = inshot_x
ry = inshot_y


# X_dx 데이터 구성 (k5 계산 시만 -y 사용, 3차항 포함)
X_dx = np.vstack([
    np.ones(len(x)), (x)/10**6, (-y)/10**6, (x**2)/10**12, (x*y)/10**12, (y**2)/10**12, (x**3)/10**15, (x**2*y)/10**15, (x*y**2)/10**15, (y**3)/10**15,
                     (rx)/10**6, (-ry)/10**6, (rx**2)/10**9, (rx*ry)/10**9, (ry**2)/10**9, (rx**3)/10**12, (rx**2*ry)/10**12, (rx*ry**2)/10**12, (ry**3)/10**12
]).T

# X_dy 데이터 구성 (3차항 포함, y를 그대로 사용)
X_dy = np.vstack([
    np.ones(len(y)), (y)/10**6, (x)/10**6, (y**2)/10**12, (y*x)/10**12, (x**2)/10**12, (y**3)/10**15, (y**2*x)/10**15, (y*x**2)/10**15, (x**3)/10**15,
                     (ry)/10**6, (rx)/10**6, (ry**2)/10**9, (ry*rx)/10**9, (rx**2)/10**9, (ry**3)/10**12, (ry**2*rx)/10**12, (ry*rx**2)/10**12
]).T



# Y_dx, Y_dy 데이터
Y_dx = df['X_reg']
Y_dy = df['Y_reg']



# 최소자승법으로 dx의 계수 구하기 (X_dx 사용)
coeff_dx = np.linalg.lstsq(X_dx, Y_dx, rcond=None)[0]

# 최소자승법으로 dy의 계수 구하기 (X_dy 사용)
coeff_dy = np.linalg.lstsq(X_dy, Y_dy, rcond=None)[0]



# dx의 결과 출력 (3차항 포함 계수명 추가)
print("Coefficients for misalign x(um):")
print(f"WK1 (Offset x): {coeff_dx[0]}")
print(f"WK3 (Scale x): {coeff_dx[1]}")
print(f"WK5 (Rotation x, with -y): {coeff_dx[2]}")  # 여기서 -y 반영됨
print(f"WK7 (x^2): {coeff_dx[3]}")
print(f"WK9 (xy): {coeff_dx[4]}")
print(f"WK11 (y^2): {coeff_dx[5]}")
print(f"WK13 (x^3): {coeff_dx[6]}")
print(f"WK15 (x^2*y): {coeff_dx[7]}")
print(f"WK17 (x*y^2): {coeff_dx[8]}")
print(f"WK19 (y^3): {coeff_dx[9]}")

print(f"RK3 (Scale x): {coeff_dx[10]}")
print(f"RK5 (Rotation x, with -y): {coeff_dx[11]}")  # 여기서 -y 반영됨
print(f"RK7 (x^2): {coeff_dx[12]}")
print(f"RK9 (xy): {coeff_dx[13]}")
print(f"RK11 (y^2): {coeff_dx[14]}")
print(f"RK13 (x^3): {coeff_dx[15]}")
print(f"RK15 (x^2*y): {coeff_dx[16]}")
print(f"RK17 (x*y^2): {coeff_dx[17]}")
print(f"RK19 (y^3): {coeff_dx[18]}")


# dy의 결과 출력 (3차항 포함 계수명 추가)
print("\nCoefficients for misalign y(um):")
print(f"WK2 (Offset y): {coeff_dy[0]}")
print(f"WK4 (Scale y): {coeff_dy[1]}")
print(f"WK6 (Rotation y): {coeff_dy[2]}")
print(f"WK8 (x^2): {coeff_dy[3]}")
print(f"WK10 (xy): {coeff_dy[4]}")
print(f"WK12 (y^2): {coeff_dy[5]}")
print(f"WK14 (x^3): {coeff_dy[6]}")
print(f"WK16 (x^2*y): {coeff_dy[7]}")
print(f"WK18 (x*y^2): {coeff_dy[8]}")
print(f"WK20 (y^3): {coeff_dy[9]}")

print(f"RK4 (Scale y): {coeff_dy[10]}")
print(f"RK6 (Rotation y): {coeff_dy[11]}")
print(f"RK8 (x^2): {coeff_dy[12]}")
print(f"RK10 (xy): {coeff_dy[13]}")
print(f"RK12 (y^2): {coeff_dy[14]}")
print(f"RK14 (x^3): {coeff_dy[15]}")
print(f"RK16 (x^2*y): {coeff_dy[16]}")
print(f"RK18 (x*y^2): {coeff_dy[17]}")
# Out:
# Coefficients for misalign x(um):
# WK1 (Offset x): 0.00047665410580924116
# WK3 (Scale x): -0.009719673617917916
# WK5 (Rotation x, with -y): -0.0008331704898858455
# WK7 (x^2): -0.005658286609556847
# WK9 (xy): 0.023013160654036365
# WK11 (y^2): -0.001367725117804953
# WK13 (x^3): -0.0005326135406948457
# WK15 (x^2*y): 0.00019892527471932945
# WK17 (x*y^2): -0.0006520022982278321
# WK19 (y^3): 8.264304297955067e-05
# RK3 (Scale x): 0.14105370647503196
# RK5 (Rotation x, with -y): 0.0015503259763927674
# RK7 (x^2): -0.002039878026246425
# RK9 (xy): -0.0007219954169213744
# RK11 (y^2): 0.00014002783751255462
# RK13 (x^3): -0.0009314668102600254
# RK15 (x^2*y): 3.262115024611042e-05
# RK17 (x*y^2): -0.00029222620012317517
# RK19 (y^3): 4.935315855063385e-05
#
# Coefficients for misalign y(um):
# WK2 (Offset y): -0.00034366308305464613
# WK4 (Scale y): -0.015729331810256472
# WK6 (Rotation y): 0.0011651283239924736
# WK8 (x^2): 0.01062381900724623
# WK10 (xy): 7.868794531119191e-05
# WK12 (y^2): -0.010820162445862752
# WK14 (x^3): -0.00015114663906783457
# WK16 (x^2*y): -0.00016310974467299814
# WK18 (x*y^2): 0.00012727998820926642
# WK20 (y^3): -0.00010123845333698084
# RK4 (Scale y): 0.041271037520970395
# RK6 (Rotation y): 0.004674983656248748
# RK8 (x^2): -0.00014223731339798847
# RK10 (xy): 0.0005490824737423511
# RK12 (y^2): 0.0009700811426259303
# RK14 (x^3): -1.767422040212833e-05
# RK16 (x^2*y): 2.7287648818910018e-05
# RK18 (x*y^2): -0.00016048882218612417
